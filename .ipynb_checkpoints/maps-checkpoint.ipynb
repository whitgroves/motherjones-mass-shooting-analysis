# %% [markdown]
# # maps
#
# #### This notebook includes several maps that visualize data (possibly) related to gun violence in the US. Sources for data will be listed here as well as the README file in the parent directory. I'm using **pandas** to process my data, and **folium** to draw into onto js maps.

# %%
import folium as fm
import pandas as pd
import numpy as np

# %%
# This is a dataset from motherjones.com compiling info on mass shootings.
# For more info, see README.
mj_shootings = pd.read_csv('mj_1982-2016.csv')
us_map = fm.Map(location=[48, -102], zoom_start=3)

# %%
# Where have these shootings taken place? Let's load the data into a folium map.
i = 0
while (i < len(mj_shootings.index)):
    case = mj_shootings.iloc[i].Case
    lat = mj_shootings.iloc[i].latitude
    long = mj_shootings.iloc[i].longitude
    
    if not np.isnan(lat):
        if not np.isnan(long):
            fm.Marker([mj_shootings.iloc[i].latitude, mj_shootings.iloc[i].longitude],
                      popup=mj_shootings.iloc[i].Case).add_to(us_map)
    
    i+=1

us_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
